# %% [markdown]
# <a href="https://colab.research.google.com/github/JibKh/NVIDIA-FlowNet2-Google-Colab/blob/master/FlowNet2_Colab_SPROJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup and Install FlowNet2

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# Sun May  2 18:58:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install torch==1.0.0 torchvision==0.2.2 -f https://download.pytorch.org/whl/cu100/torch_stable.html
# !pip install pypng
# !pip install tensorboardx
# !pip install setproctitle colorama scipy==1.1.0
# !pip install flowiz -U
# Out:
# Looking in links: https://download.pytorch.org/whl/cu100/torch_stable.html
# Collecting torch==1.0.0
#   Downloading https://files.pythonhosted.org/packages/f5/3b/0b8de6e654c2983898564226792c6f09d9bcaba97b7b29c40e4ed4ae43ed/torch-1.0.0-cp37-cp37m-manylinux1_x86_64.whl (591.8MB)
#      |████████████████████████████████| 591.8MB 27kB/s
# Collecting torchvision==0.2.2
#   Downloading https://files.pythonhosted.org/packages/ce/a1/66d72a2fe580a9f0fcbaaa5b976911fbbde9dce9b330ba12791997b856e9/torchvision-0.2.2-py2.py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Collecting tqdm==4.19.9
#   Downloading https://files.pythonhosted.org/packages/b3/c4/b67cf1ab472b770e08e94105a0c7ca7032cd070627c435f5998c9cf6e64f/tqdm-4.19.9-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 9.2MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.2.2) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.2.2) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.2.2) (1.19.5)
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.0.0 which is incompatible.
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.19.9 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement tqdm>=4.36.1, but you'll have tqdm 4.19.9 which is incompatible.
# Installing collected packages: torch, tqdm, torchvision
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# Successfully installed torch-1.0.0 torchvision-0.2.2 tqdm-4.19.9
# Collecting pypng
#   Downloading https://files.pythonhosted.org/packages/bc/fb/f719f1ac965e2101aa6ea6f54ef8b40f8fbb033f6ad07c017663467f5147/pypng-0.0.20.tar.gz (649kB)
#      |████████████████████████████████| 655kB 13.7MB/s
# Building wheels for collected packages: pypng
#   Building wheel for pypng (setup.py) ... done
#   Created wheel for pypng: filename=pypng-0.0.20-cp37-none-any.whl size=67163 sha256=38b459971faaaf11880e19e79a44a9cefc5122e0e34b1f62d23bd231c0db7e55
#   Stored in directory: /root/.cache/pip/wheels/41/6b/ef/0493b536b6d4722c2ae9486691b1d49b922b9877922beeabb3
# Successfully built pypng
# Installing collected packages: pypng
# Successfully installed pypng-0.0.20
# Collecting tensorboardx
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 17.7MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (1.19.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardx) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardx) (56.0.0)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-2.2
# Collecting setproctitle
#   Downloading https://files.pythonhosted.org/packages/97/5c/16a6e69febfbee3f1a1a8c4318d1f054ff4d3ef2a61b233937c316cba06d/setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/40/de/0c22c6754370ba6b1fa8e53bd6e514d4a41a181125d405a501c215cbdbd6/scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 103kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: setproctitle, colorama, scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed colorama-0.4.4 scipy-1.1.0 setproctitle-1.2.2
# Collecting flowiz
#   Downloading https://files.pythonhosted.org/packages/8c/f5/7a0edc26cffd1f8a426a8b0c61bce05296136a6c9057347f995e5e27cf13/flowiz-2.3.1-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 18.6MB/s
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.7/dist-packages (from flowiz) (3.2.2)
# Collecting eel
#   Downloading https://files.pythonhosted.org/packages/b3/c2/7dc22cc9ea23f0339316d6d249392d3ce67190430f2b05a316f3471ae15d/Eel-0.14.0.tar.gz
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from flowiz) (1.19.5)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from flowiz) (4.19.9)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flowiz) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flowiz) (1.3.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flowiz) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flowiz) (0.10.0)
# Collecting bottle
#   Downloading https://files.pythonhosted.org/packages/bf/44/aeafdd6ca05a8e1c3f91eeeb272a202d5cb1b3b23730a5ca686a81c48d24/bottle-0.12.19-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 11.2MB/s
# Collecting bottle-websocket
#   Downloading https://files.pythonhosted.org/packages/17/8e/a22666b4bb0a6e31de579504077df2b1c2f1438136777c728e6cfabef295/bottle-websocket-0.2.9.tar.gz
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.7/dist-packages (from eel->flowiz) (0.16.0)
# Collecting whichcraft
#   Downloading https://files.pythonhosted.org/packages/b5/a2/81887a0dae2e4d2adc70d9a3557fdda969f863ced51cd3c47b587d25bce5/whichcraft-0.6.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->flowiz) (1.15.0)
# Collecting gevent-websocket
#   Downloading https://files.pythonhosted.org/packages/7b/84/2dc373eb6493e00c884cc11e6c059ec97abae2678d42f06bf780570b0193/gevent_websocket-0.10.1-py3-none-any.whl
# Collecting gevent
#   Downloading https://files.pythonhosted.org/packages/3e/85/df3d1fd2b60a87455475f93012861b76a411d27ba4a0859939adbe2c9dc3/gevent-21.1.2-cp37-cp37m-manylinux2010_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 50.2MB/s
# Collecting zope.interface
#   Downloading https://files.pythonhosted.org/packages/bb/a7/94e1a92c71436f934cdd2102826fa041c83dcb7d21dd0f1fb1a57f6e0620/zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251kB)
#      |████████████████████████████████| 256kB 52.8MB/s
# Requirement already satisfied, skipping upgrade: greenlet<2.0,>=0.4.17; platform_python_implementation == "CPython" in /usr/local/lib/python3.7/dist-packages (from gevent->gevent-websocket->bottle-websocket->eel->flowiz) (1.0.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent->gevent-websocket->bottle-websocket->eel->flowiz) (56.0.0)
# Collecting zope.event
#   Downloading https://files.pythonhosted.org/packages/9e/85/b45408c64f3b888976f1d5b37eed8d746b8d5729a66a49ec846fda27d371/zope.event-4.5.0-py2.py3-none-any.whl
# Building wheels for collected packages: eel, bottle-websocket
#   Building wheel for eel (setup.py) ... done
#   Created wheel for eel: filename=Eel-0.14.0-cp37-none-any.whl size=17462 sha256=8f2322b01a088e514f4ea7446e2d4ce2473fc3f48f8bb788df54ccbc151c9873
#   Stored in directory: /root/.cache/pip/wheels/68/a8/f9/0bb7b895584b80f4beabebfb8dcfdb8c7b0db2420b9c2a4821
#   Building wheel for bottle-websocket (setup.py) ... done
#   Created wheel for bottle-websocket: filename=bottle_websocket-0.2.9-cp37-none-any.whl size=2347 sha256=efae6b9c929fd483971abefc2fdec5e1412f0b1aab8194ba947d687fb31bd128
#   Stored in directory: /root/.cache/pip/wheels/1e/fd/80/af47541f053f14f4e5fd5927c91a7615358826429ba036152d
# Successfully built eel bottle-websocket
# Installing collected packages: bottle, zope.interface, zope.event, gevent, gevent-websocket, bottle-websocket, whichcraft, eel, flowiz
# Successfully installed bottle-0.12.19 bottle-websocket-0.2.9 eel-0.14.0 flowiz-2.3.1 gevent-21.1.2 gevent-websocket-0.10.1 whichcraft-0.6.1 zope.event-4.5.0 zope.interface-5.4.0

# %%
import os
# get flownet2-pytorch source
# !git clone https://github.com/NVIDIA/flownet2-pytorch.git
# !mv /content/flownet2-pytorch /content/flownet2pytorch
os.chdir('./flownet2pytorch')
# install custom layers
# !bash install.sh
# Out:
# Cloning into 'flownet2-pytorch'...
# remote: Enumerating objects: 557, done.
# remote: Total 557 (delta 0), reused 0 (delta 0), pack-reused 557
# Receiving objects: 100% (557/557), 6.28 MiB | 34.21 MiB/s, done.
# Resolving deltas: 100% (312/312), done.
# running install
# running bdist_egg
# running egg_info
# creating correlation_cuda.egg-info
# writing correlation_cuda.egg-info/PKG-INFO
# writing dependency_links to correlation_cuda.egg-info/dependency_links.txt
# writing top-level names to correlation_cuda.egg-info/top_level.txt
# writing manifest file 'correlation_cuda.egg-info/SOURCES.txt'
# writing manifest file 'correlation_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'correlation_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c correlation_cuda.cc -o build/temp.linux-x86_64-3.7/correlation_cuda.o -std=c++11 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=correlation_cuda -D_GLIBCXX_USE_CXX11_ABI=0
# In file included from correlation_cuda.cc:1:0:
# /usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include/torch/torch.h:7:2: warning: #warning "Including torch/torch.h for C++ extensions is deprecated. Please include torch/extension.h" [-Wcpp]
#  #warning \
#   ^~~~~~~
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c correlation_cuda_kernel.cu -o build/temp.linux-x86_64-3.7/correlation_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_70,code=compute_70 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=correlation_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# creating build/lib.linux-x86_64-3.7
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/correlation_cuda.o build/temp.linux-x86_64-3.7/correlation_cuda_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.7/correlation_cuda.cpython-37m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.7/correlation_cuda.cpython-37m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for correlation_cuda.cpython-37m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/correlation_cuda.py to correlation_cuda.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying correlation_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying correlation_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying correlation_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying correlation_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.correlation_cuda.cpython-37: module references __file__
# creating dist
# creating 'dist/correlation_cuda-0.0.0-py3.7-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing correlation_cuda-0.0.0-py3.7-linux-x86_64.egg
# creating /root/.local/lib/python3.7/site-packages/correlation_cuda-0.0.0-py3.7-linux-x86_64.egg
# Extracting correlation_cuda-0.0.0-py3.7-linux-x86_64.egg to /root/.local/lib/python3.7/site-packages
# Adding correlation-cuda 0.0.0 to easy-install.pth file
#
# Installed /root/.local/lib/python3.7/site-packages/correlation_cuda-0.0.0-py3.7-linux-x86_64.egg
# Processing dependencies for correlation-cuda==0.0.0
# Finished processing dependencies for correlation-cuda==0.0.0
# running install
# running bdist_egg
# running egg_info
# creating resample2d_cuda.egg-info
# writing resample2d_cuda.egg-info/PKG-INFO
# writing dependency_links to resample2d_cuda.egg-info/dependency_links.txt
# writing top-level names to resample2d_cuda.egg-info/top_level.txt
# writing manifest file 'resample2d_cuda.egg-info/SOURCES.txt'
# writing manifest file 'resample2d_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'resample2d_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c resample2d_cuda.cc -o build/temp.linux-x86_64-3.7/resample2d_cuda.o -std=c++11 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=resample2d_cuda -D_GLIBCXX_USE_CXX11_ABI=0
# In file included from resample2d_cuda.cc:2:0:
# /usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include/torch/torch.h:7:2: warning: #warning "Including torch/torch.h for C++ extensions is deprecated. Please include torch/extension.h" [-Wcpp]
#  #warning \
#   ^~~~~~~
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c resample2d_kernel.cu -o build/temp.linux-x86_64-3.7/resample2d_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_70,code=compute_70 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=resample2d_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# creating build/lib.linux-x86_64-3.7
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/resample2d_cuda.o build/temp.linux-x86_64-3.7/resample2d_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.7/resample2d_cuda.cpython-37m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.7/resample2d_cuda.cpython-37m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for resample2d_cuda.cpython-37m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/resample2d_cuda.py to resample2d_cuda.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.resample2d_cuda.cpython-37: module references __file__
# creating dist
# creating 'dist/resample2d_cuda-0.0.0-py3.7-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing resample2d_cuda-0.0.0-py3.7-linux-x86_64.egg
# creating /root/.local/lib/python3.7/site-packages/resample2d_cuda-0.0.0-py3.7-linux-x86_64.egg
# Extracting resample2d_cuda-0.0.0-py3.7-linux-x86_64.egg to /root/.local/lib/python3.7/site-packages
# Adding resample2d-cuda 0.0.0 to easy-install.pth file
#
# Installed /root/.local/lib/python3.7/site-packages/resample2d_cuda-0.0.0-py3.7-linux-x86_64.egg
# Processing dependencies for resample2d-cuda==0.0.0
# Finished processing dependencies for resample2d-cuda==0.0.0
# running install
# running bdist_egg
# running egg_info
# creating channelnorm_cuda.egg-info
# writing channelnorm_cuda.egg-info/PKG-INFO
# writing dependency_links to channelnorm_cuda.egg-info/dependency_links.txt
# writing top-level names to channelnorm_cuda.egg-info/top_level.txt
# writing manifest file 'channelnorm_cuda.egg-info/SOURCES.txt'
# writing manifest file 'channelnorm_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'channelnorm_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c channelnorm_cuda.cc -o build/temp.linux-x86_64-3.7/channelnorm_cuda.o -std=c++11 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=channelnorm_cuda -D_GLIBCXX_USE_CXX11_ABI=0
# In file included from channelnorm_cuda.cc:1:0:
# /usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include/torch/torch.h:7:2: warning: #warning "Including torch/torch.h for C++ extensions is deprecated. Please include torch/extension.h" [-Wcpp]
#  #warning \
#   ^~~~~~~
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.7/dist-packages/torch/lib/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c channelnorm_kernel.cu -o build/temp.linux-x86_64-3.7/channelnorm_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_70,code=compute_70 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=channelnorm_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# creating build/lib.linux-x86_64-3.7
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/channelnorm_cuda.o build/temp.linux-x86_64-3.7/channelnorm_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.7/channelnorm_cuda.cpython-37m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.7/channelnorm_cuda.cpython-37m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for channelnorm_cuda.cpython-37m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/channelnorm_cuda.py to channelnorm_cuda.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying channelnorm_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying channelnorm_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying channelnorm_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying channelnorm_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.channelnorm_cuda.cpython-37: module references __file__
# creating dist
# creating 'dist/channelnorm_cuda-0.0.0-py3.7-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing channelnorm_cuda-0.0.0-py3.7-linux-x86_64.egg
# creating /root/.local/lib/python3.7/site-packages/channelnorm_cuda-0.0.0-py3.7-linux-x86_64.egg
# Extracting channelnorm_cuda-0.0.0-py3.7-linux-x86_64.egg to /root/.local/lib/python3.7/site-packages
# Adding channelnorm-cuda 0.0.0 to easy-install.pth file
#
# Installed /root/.local/lib/python3.7/site-packages/channelnorm_cuda-0.0.0-py3.7-linux-x86_64.egg
# Processing dependencies for channelnorm-cuda==0.0.0
# Finished processing dependencies for channelnorm-cuda==0.0.0

# %%
import os
os.sys.path.append('/root/.local/lib/python3.6/site-packages/resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg')
os.sys.path.append('/root/.local/lib/python3.6/site-packages/correlation_cuda-0.0.0-py3.6-linux-x86_64.egg')
os.sys.path.append( '/root/.local/lib/python3.6/site-packages/channelnorm_cuda-0.0.0-py3.6-linux-x86_64.egg')

# %%
# !python main.py --help
# Out:
# usage: main.py [-h] [--start_epoch START_EPOCH] [--total_epochs TOTAL_EPOCHS]
#                [--batch_size BATCH_SIZE] [--train_n_batches TRAIN_N_BATCHES]
#                [--crop_size CROP_SIZE [CROP_SIZE ...]]
#                [--gradient_clip GRADIENT_CLIP]
#                [--schedule_lr_frequency SCHEDULE_LR_FREQUENCY]
#                [--schedule_lr_fraction SCHEDULE_LR_FRACTION]
#                [--rgb_max RGB_MAX] [--number_workers NUMBER_WORKERS]
#                [--number_gpus NUMBER_GPUS] [--no_cuda] [--seed SEED]
#                [--name NAME] [--save SAVE]
#                [--validation_frequency VALIDATION_FREQUENCY]
#                [--validation_n_batches VALIDATION_N_BATCHES]
#                [--render_validation] [--inference] [--inference_visualize]
#                [--inference_size INFERENCE_SIZE [INFERENCE_SIZE ...]]
#                [--inference_batch_size INFERENCE_BATCH_SIZE]
#                [--inference_n_batches INFERENCE_N_BATCHES] [--save_flow]
#                [--resume PATH] [--log_frequency LOG_FREQUENCY]
#                [--skip_training] [--skip_validation] [--fp16]
#                [--fp16_scale FP16_SCALE]
#                [--model {ChannelNorm,FlowNet2,FlowNet2C,FlowNet2CS,FlowNet2CSS,FlowNet2S,FlowNet2SD,Resample2d,tofp16,tofp32}]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --start_epoch START_EPOCH
#   --total_epochs TOTAL_EPOCHS
#   --batch_size BATCH_SIZE, -b BATCH_SIZE
#                         Batch size
#   --train_n_batches TRAIN_N_BATCHES
#                         Number of min-batches per epoch. If < 0, it will be
#                         determined by training_dataloader
#   --crop_size CROP_SIZE [CROP_SIZE ...]
#                         Spatial dimension to crop training samples for
#                         training
#   --gradient_clip GRADIENT_CLIP
#   --schedule_lr_frequency SCHEDULE_LR_FREQUENCY
#                         in number of iterations (0 for no schedule)
#   --schedule_lr_fraction SCHEDULE_LR_FRACTION
#   --rgb_max RGB_MAX
#   --number_workers NUMBER_WORKERS, -nw NUMBER_WORKERS, --num_workers NUMBER_WORKERS
#   --number_gpus NUMBER_GPUS, -ng NUMBER_GPUS
#                         number of GPUs to use
#   --no_cuda
#   --seed SEED
#   --name NAME           a name to append to the save directory
#   --save SAVE, -s SAVE  directory for saving
#   --validation_frequency VALIDATION_FREQUENCY
#                         validate every n epochs
#   --validation_n_batches VALIDATION_N_BATCHES
#   --render_validation   run inference (save flows to file) and every
#                         validation_frequency epoch
#   --inference
#   --inference_visualize
#                         visualize the optical flow during inference
#   --inference_size INFERENCE_SIZE [INFERENCE_SIZE ...]
#                         spatial size divisible by 64. default (-1,-1) -
#                         largest possible valid size would be used
#   --inference_batch_size INFERENCE_BATCH_SIZE
#   --inference_n_batches INFERENCE_N_BATCHES
#   --save_flow           save predicted flows to file
#   --resume PATH         path to latest checkpoint (default: none)
#   --log_frequency LOG_FREQUENCY, --summ_iter LOG_FREQUENCY
#                         Log every n batches
#   --skip_training
#   --skip_validation
#   --fp16                Run model in pseudo-fp16 mode (fp16 storage fp32
#                         math).
#   --fp16_scale FP16_SCALE
#                         Loss scaling, positive power of 2 values can improve
#                         fp16 convergence.
#
# Model:
#   --model {ChannelNorm,FlowNet2,FlowNet2C,FlowNet2CS,FlowNet2CSS,FlowNet2S,FlowNet2SD,Resample2d,tofp16,tofp32}

# %% [markdown]
# # User Input and Restart

# %%
# If you have a video put 1. If you have frames put 2.
# Based on your choice, update the below cells accordingly
video_frames = 1

# If you would like to visualize the flow frames. This WILL DELETE ALL THE FLOWFRAMES GENERATED TO SAVE STORAGE.
visualize = False

# %%
# Video Input

if video_frames == 1:

  video_name = 'test.mp4' # If you have a video you want to run inference on. Please include .mp4 or whatever extension the video has.
  video_local_gdrive = 2 # If you want to upload a video from your local drive, choose 1. If from your google drive, choose 2. If some other option, go to section "Upload Video".
  
  # If your video is on gdrive, please add Gdrive ID here.
  if video_local_gdrive == 2:
    video_gdrive = '1UcL20kKE5LA_Gn0ybxIYGVbya6NxcirF' # File_id for your google drive video. Use this link to see how to get file ID https://docs.meiro.io/books/meiro-integrations/page/where-can-i-find-the-file-id-on-google-drive#:~:text=To%20locate%20the%20File%20ID,%3D%60%20is%20the%20File%20ID.

# %%
# Frames Input

if video_frames == 2:

  # Mount Gdrive
  from google.colab import drive
  drive.mount('/content/drive')

  frames_zip_name = "2 - Arabic.zip" # If you have the frames, enter its zip file here. For ex: "3 - Video.zip"
  frames_directory = '../gdrive/My Drive/Hajj Videos/Frames/' # Where the frames are located. If its in gdrive: '../gdrive/My Drive/Location of Zip/' Change the Location of Zip to wherever yours is stored.

# %%
# Skip / Average Options

no_frames_skip = 1 # How many frames you want skipped. For eg if its 2 then from frames 1,2,3,4,5,6,7 we take frames 1,4,7. Leave at None to not skip frames.

# Only one can work at a time
no_average_frames = None # How many frames you want to average. Leave at None if you don't want to avg.
running_average = False # If you want to visually see running average

# %%
# DO NOT TOUCH

flow_video_name = 'flowvid.mp4'

# FOR VIDEOS
if video_frames == 1:

  # This will prompt you to upload the video from your local machine
  if video_local_gdrive == 1:

    from google.colab import files
    uploaded = files.upload()
    if video_name != list(uploaded.keys())[0]:
      video_name = list(uploaded.keys())[0]

  # This downloads the gdrive video
  elif video_local_gdrive == 2:

    # This will download the video
    # !gdown --id $video_gdrive

# FOR FRAMES
if video_frames == 2:
  
  # !mkdir -p ./frames
  unzip_file = frames_directory + frames_zip_name
  # !unzip '$unzip_file' -d ./frames
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UcL20kKE5LA_Gn0ybxIYGVbya6NxcirF
# To: /content/flownet2pytorch/test.mp4
# 10.2MB [00:00, 38.7MB/s]

# %%
# THIS WILL DELETE ALL THE FRAMES, FLOW FRAMES, OUTPUT FILES, FLOW VIDEO.
# If you would like to keep something, make sure to comment it out and save it before running this.

# To restart and run again. Change any parameters above and then go click the "User Input and Restart" cell. Then Runtime -> Run After.

# !rm -r ./frames
# !rm -r ./Flo
# !rm -r ./FlowFrames
# !rm -r ./output
# !rm ./$video_name
# !rm -r ./Average_Frames
# !rm -r ./Running_Avg_Frames
# !rm -r ./FlowVideo
# !pip install setproctitle colorama scipy==1.1.0
# Out:
# rm: cannot remove './frames': No such file or directory
# rm: cannot remove './Flo': No such file or directory
# rm: cannot remove './FlowFrames': No such file or directory
# rm: cannot remove './output': No such file or directory
# rm: cannot remove './Average_Frames': No such file or directory
# rm: cannot remove './Running_Avg_Frames': No such file or directory
# rm: cannot remove './FlowVideo': No such file or directory
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (1.2.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.4)
# Requirement already satisfied: scipy==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)

# %% [markdown]
# # Training and Validation - Not tested

# %% [markdown]
# If you do not want to train your model, you can skip this and move on to inference.
#
# The dataset my team used is quite large and we have unlimited storage on OneDrive. So we have mounted OneDrive to read and write data to. <br>
# To understand how to use it: https://www.youtube.com/watch?v=U6YPgARhRzA&t=255s&ab_channel=BoostUpStation

# %% [markdown]
# ## OneDrive

# %%
# !wget https://downloads.rclone.org/v1.50.1/rclone-v1.50.1-linux-amd64.deb
# !apt install ./rclone-v1.50.1-linux-amd64.deb

# %%
# !rclone config

# %%
# !sudo mkdir /content/onedrive
# !nohup rclone --vfs-cache-mode writes mount onedrive: /content/onedrive &

# %% [markdown]
# ## Train and Validate

# %%
# !python main.py --batch_size 8 --model FlowNet2 --loss=L1Loss --optimizer=Adam --optimizer_lr=1e-4 \
# --training_dataset MpiSintelFinal --training_dataset_root /path/to/mpi-sintel/final/dataset  \
# --validation_dataset MpiSintelClean --validation_dataset_root /path/to/mpi-sintel/clean/dataset

# %% [markdown]
# # Run the inference

# %% [markdown]
# ## Setup Video

# %% [markdown]
# ### Converting video to frames

# %%
import os

if video_frames == 1:
  def mkdir_ifnotexists(dir):
      if os.path.exists(dir):
          return
      os.mkdir(dir)

# %%
if video_frames == 1:
  vid_file = video_name
  frame_pth = './frames'
  mkdir_ifnotexists(frame_pth)
  cmd = "ffmpeg -i %s -start_number 0 -vsync 0 %s/frame_%%06d.png" % (
              vid_file,
              frame_pth,
          )
  os.system(cmd)

# %% [markdown]
# ## Setup Frames

# %% [markdown]
# ### Rename Frames

# %%
# !ls ./frames | wc -l # Use to recheck if number of frames is consistent and nothing went wrong.
# Out:
# 183

# %%
if video_frames == 2:
  import os

  file_dir = "./frames/"
  for count, filename in enumerate(sorted(os.listdir(file_dir))):
    # print(filename)
    if filename[-11:] == "_UTC+01.jpg":
      src = file_dir + filename
      dst = file_dir + str(count).zfill(6) + '.png'
      os.rename(src, dst)

# %%
# !ls ./frames | wc -l # Use to recheck if number of frames is consistent and nothing went wrong.
# Out:
# 183

# %% [markdown]
# ### Skip Frames

# %%
# !ls ./frames | wc -l # Use to recheck if number of frames is consistent and nothing went wrong.
# Out:
# 183

# %%
if no_frames_skip != None:
  directory = "./frames"

  temp_skip = no_frames_skip

  for i, file in enumerate(sorted(os.listdir(directory))):
    if (temp_skip != 0) and (file[-4:] == ".png"):
      os.remove(directory + '/' + file)
      temp_skip = temp_skip - 1
      continue
    temp_skip = no_frames_skip


# if no_frames_skip != None:
#   directory = './frames'
#   # no_frames_skip = 2

#   for i, file in enumerate(sorted(os.listdir(directory))):
#     if (file[-4:] == ".png") and (int(file[0:-4]) % no_frames_skip == 0):
#       # print(file)
#       os.remove(directory+'/' + file)

# %%
if no_frames_skip != None:
  import os

  file_dir = "./frames/"
  for count, filename in enumerate(sorted(os.listdir(file_dir))):
    # print(filename)
    if filename[-4:] == ".png":
      src = file_dir + filename
      dst = file_dir + str(count).zfill(6) + '.png'
      os.rename(src, dst)

# %%
# !ls ./frames | wc -l # Use to recheck if number of frames is consistent and nothing went wrong.
# Out:
# 91

# %% [markdown]
# ## Run Inference

# %% [markdown]
# Download the checkpoint. <br>
# If you have your own checkpoint after training, skip this step.

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id='1hF8vS6YeHkx3j2pfCeQqqZGwA_PJq_Da',dest_path='./FlowNet2_checkpoint.pth.tar')
# Out:
# Downloading 1hF8vS6YeHkx3j2pfCeQqqZGwA_PJq_Da into ./FlowNet2_checkpoint.pth.tar... Done.

# %% [markdown]
# Run inference. <br>
# You can learn more about each command from here: https://towardsdatascience.com/generating-optical-flow-using-nvidia-flownet2-pytorch-implementation-d7b0ae6f8320

# %%
# !python main.py --inference --model FlowNet2 --save_flow --save ./output --inference_dataset ImagesFromFolder --inference_dataset_root ./frames/ --resume ./FlowNet2_checkpoint.pth.tar
# Out:
# Parsing Arguments
#   [0.031s] batch_size: 8
#   [0.031s] crop_size: [256, 256]
#   [0.031s] fp16: False
#   [0.031s] fp16_scale: 1024.0
#   [0.031s] gradient_clip: None
#   [0.031s] inference: True
#   [0.031s] inference_batch_size: 1
#   [0.031s] inference_dataset: ImagesFromFolder
#   [0.031s] inference_dataset_iext: png
#   [0.031s] inference_dataset_replicates: 1
#   [0.031s] inference_dataset_root: ./frames/
#   [0.031s] inference_n_batches: -1
#   [0.031s] inference_size: [-1, -1]
#   [0.031s] inference_visualize: False
#   [0.031s] log_frequency: 1
#   [0.031s] loss: L1Loss
#   [0.031s] model: FlowNet2
#   [0.031s] model_batchNorm: False
#   [0.031s] model_div_flow: 20.0
#   [0.031s] name: run
#   [0.031s] no_cuda: False
#   [0.031s] number_gpus: 1
#   [0.031s] number_workers: 8
#   [0.031s] optimizer: Adam
#   [0.031s] optimizer_amsgrad: False
#   [0.031s] optimizer_betas: (0.9, 0.999)
#   [0.031s] optimizer_eps: 1e-08
#   [0.031s] optimizer_lr: 0.001
#   [0.031s] optimizer_weight_decay: 0
#   [0.031s] render_validation: False
#   [0.031s] resume: ./FlowNet2_checkpoint.pth.tar
#   [0.031s] rgb_max: 255.0
#   [0.031s] save: ./output
#   [0.031s] save_flow: True
#   [0.031s] schedule_lr_fraction: 10
#   [0.031s] schedule_lr_frequency: 0
#   [0.031s] seed: 1
#   [0.031s] skip_training: False
#   [0.032s] skip_validation: False
#   [0.032s] start_epoch: 1
#   [0.032s] total_epochs: 10000
#   [0.032s] train_n_batches: -1
#   [0.032s] training_dataset: MpiSintelFinal
#   [0.032s] training_dataset_replicates: 1
#   [0.032s] training_dataset_root: ./MPI-Sintel/flow/training
#   [0.032s] validation_dataset: MpiSintelClean
#   [0.032s] validation_dataset_replicates: 1
#   [0.032s] validation_dataset_root: ./MPI-Sintel/flow/training
#   [0.032s] validation_frequency: 5
#   [0.032s] validation_n_batches: -1
#   [0.034s] Operation finished
#
# Source Code
#   Current Git Hash: b'2e9e010c98931bc7cef3eb063b195f1e0ab470ba'
#
# Initializing Datasets
#   [0.063s] Inference Dataset: ImagesFromFolder
#   [0.207s] Inference Input: [3, 2, 1024, 1920]
#   [0.319s] Inference Targets: [3, 2, 1024, 1920]
#   [0.319s] Operation finished
#
# Building FlowNet2 model
#   [3.932s] Effective Batch Size: 8
#   [3.933s] Number of parameters: 162518834
#   [3.933s] Initializing CUDA
#   [6.763s] Parallelizing
#   [6.764s] Loading checkpoint './FlowNet2_checkpoint.pth.tar'
#   [7.142s] Loaded checkpoint './FlowNet2_checkpoint.pth.tar' (at epoch 0)
#   [7.142s] Initializing save directory: ./output
#   [7.145s] Operation finished
#
# Initializing Adam Optimizer
#   [0.001s] amsgrad = False (<class 'bool'>)
#   [0.001s] weight_decay = 0 (<class 'int'>)
#   [0.001s] eps = 1e-08 (<class 'float'>)
#   [0.001s] betas = (0.9, 0.999) (<class 'tuple'>)
#   [0.001s] lr = 0.001 (<class 'float'>)
#   [0.001s] Operation finished
#
# Overall Progress:   0%|                                                       | 0/1 [00:00<?, ?it/s]
# Inferencing :   0%|                                                        | 0/90.0 [00:00<?, ?it/s]THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=405 error=11 : invalid argument
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2423: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
# Inference Averages for Epoch 0: L1: 0.025, EPE: 0.044:   0%|               | 0/90.0 [00:03<?, ?it/s]
# Inference Averages for Epoch 0: L1: 0.025, EPE: 0.044:   1%|       | 1/90.0 [00:03<05:25,  3.65s/it]
# Inference Averages for Epoch 0: L1: 0.025, EPE: 0.044:   1%|       | 1/90.0 [00:03<05:25,  3.65s/it]
# Inference Averages for Epoch 0: L1: 0.022, EPE: 0.038:   1%|       | 1/90.0 [00:04<05:25,  3.65s/it]
# Inference Averages for Epoch 0: L1: 0.022, EPE: 0.038:   2%|▏      | 2/90.0 [00:04<04:13,  2.88s/it]
# Inference Averages for Epoch 0: L1: 0.022, EPE: 0.038:   2%|▏      | 2/90.0 [00:04<04:13,  2.88s/it]
# Inference Averages for Epoch 0: L1: 0.024, EPE: 0.041:   2%|▏      | 2/90.0 [00:05<04:13,  2.88s/it]
# Inference Averages for Epoch 0: L1: 0.024, EPE: 0.041:   3%|▏      | 3/90.0 [00:05<03:14,  2.24s/it]
# Inference Averages for Epoch 0: L1: 0.024, EPE: 0.041:   3%|▏      | 3/90.0 [00:05<03:14,  2.24s/it]
# Inference Averages for Epoch 0: L1: 0.053, EPE: 0.092:   3%|▏      | 3/90.0 [00:06<03:14,  2.24s/it]
# Inference Averages for Epoch 0: L1: 0.053, EPE: 0.092:   4%|▎      | 4/90.0 [00:06<02:33,  1.79s/it]
# Inference Averages for Epoch 0: L1: 0.053, EPE: 0.092:   4%|▎      | 4/90.0 [00:06<02:33,  1.79s/it]
# Inference Averages for Epoch 0: L1: 0.052, EPE: 0.090:   4%|▎      | 4/90.0 [00:06<02:33,  1.79s/it]
# Inference Averages for Epoch 0: L1: 0.052, EPE: 0.090:   6%|▍      | 5/90.0 [00:06<02:04,  1.47s/it]
# Inference Averages for Epoch 0: L1: 0.052, EPE: 0.090:   6%|▍      | 5/90.0 [00:06<02:04,  1.47s/it]
# Inference Averages for Epoch 0: L1: 0.057, EPE: 0.099:   6%|▍      | 5/90.0 [00:07<02:04,  1.47s/it]
# Inference Averages for Epoch 0: L1: 0.057, EPE: 0.099:   7%|▍      | 6/90.0 [00:07<01:44,  1.24s/it]
# Inference Averages for Epoch 0: L1: 0.057, EPE: 0.099:   7%|▍      | 6/90.0 [00:07<01:44,  1.24s/it]
# Inference Averages for Epoch 0: L1: 0.063, EPE: 0.109:   7%|▍      | 6/90.0 [00:08<01:44,  1.24s/it]
# Inference Averages for Epoch 0: L1: 0.063, EPE: 0.109:   8%|▌      | 7/90.0 [00:08<01:30,  1.09s/it]
# Inference Averages for Epoch 0: L1: 0.063, EPE: 0.109:   8%|▌      | 7/90.0 [00:08<01:30,  1.09s/it]
# Inference Averages for Epoch 0: L1: 0.071, EPE: 0.123:   8%|▌      | 7/90.0 [00:09<01:30,  1.09s/it]
# Inference Averages for Epoch 0: L1: 0.071, EPE: 0.123:   9%|▌      | 8/90.0 [00:09<01:20,  1.02it/s]
# Inference Averages for Epoch 0: L1: 0.071, EPE: 0.123:   9%|▌      | 8/90.0 [00:09<01:20,  1.02it/s]
# Inference Averages for Epoch 0: L1: 0.084, EPE: 0.145:   9%|▌      | 8/90.0 [00:09<01:20,  1.02it/s]
# Inference Averages for Epoch 0: L1: 0.084, EPE: 0.145:  10%|▋      | 9/90.0 [00:09<01:14,  1.09it/s]
# Inference Averages for Epoch 0: L1: 0.084, EPE: 0.145:  10%|▋      | 9/90.0 [00:09<01:14,  1.09it/s]
# Inference Averages for Epoch 0: L1: 0.094, EPE: 0.163:  10%|▋      | 9/90.0 [00:10<01:14,  1.09it/s]
# Inference Averages for Epoch 0: L1: 0.094, EPE: 0.163:  11%|▋     | 10/90.0 [00:10<01:08,  1.16it/s]
# Inference Averages for Epoch 0: L1: 0.094, EPE: 0.163:  11%|▋     | 10/90.0 [00:10<01:08,  1.16it/s]
# Inference Averages for Epoch 0: L1: 0.110, EPE: 0.190:  11%|▋     | 10/90.0 [00:11<01:08,  1.16it/s]
# Inference Averages for Epoch 0: L1: 0.110, EPE: 0.190:  12%|▋     | 11/90.0 [00:11<01:04,  1.22it/s]
# Inference Averages for Epoch 0: L1: 0.110, EPE: 0.190:  12%|▋     | 11/90.0 [00:11<01:04,  1.22it/s]
# Inference Averages for Epoch 0: L1: 0.122, EPE: 0.211:  12%|▋     | 11/90.0 [00:12<01:04,  1.22it/s]
# Inference Averages for Epoch 0: L1: 0.122, EPE: 0.211:  13%|▊     | 12/90.0 [00:12<01:02,  1.25it/s]
# Inference Averages for Epoch 0: L1: 0.122, EPE: 0.211:  13%|▊     | 12/90.0 [00:12<01:02,  1.25it/s]
# Inference Averages for Epoch 0: L1: 0.133, EPE: 0.231:  13%|▊     | 12/90.0 [00:12<01:02,  1.25it/s]
# Inference Averages for Epoch 0: L1: 0.133, EPE: 0.231:  14%|▊     | 13/90.0 [00:12<01:00,  1.28it/s]
# Inference Averages for Epoch 0: L1: 0.133, EPE: 0.231:  14%|▊     | 13/90.0 [00:12<01:00,  1.28it/s]
# Inference Averages for Epoch 0: L1: 0.150, EPE: 0.261:  14%|▊     | 13/90.0 [00:13<01:00,  1.28it/s]
  1.36it/s]
# Inference Averages for Epoch 0: L1: 0.434, EPE: 0.752:  98%|█████▊| 88/90.0 [01:09<00:01,  1.36it/s]
# Inference Averages for Epoch 0: L1: 0.434, EPE: 0.752:  99%|█████▉| 89/90.0 [01:09<00:00,  1.35it/s]
# Inference Averages for Epoch 0: L1: 0.434, EPE: 0.752:  99%|█████▉| 89/90.0 [01:09<00:00,  1.35it/s]
# Inference Averages for Epoch 0: L1: 0.432, EPE: 0.749:  99%|█████▉| 89/90.0 [01:09<00:00,  1.35it/s]
# Inference Averages for Epoch 0: L1: 0.432, EPE: 0.749: 100%|██████| 90/90.0 [01:09<00:00,  1.37it/s]
# Inference Averages for Epoch 0: L1: 0.432, EPE: 0.749: 100%|██████| 90/90.0 [01:09<00:00,  1.37it/s]
# Overall Progress: 100%|███████████████████████████████████████████████| 1/1 [01:09<00:00, 69.99s/it]

# %% [markdown]
# # Average

# %%
if running_average == True or no_average_frames != None:
  import numpy as np
  from pathlib import Path
  import os
  from utils.flow_utils import writeFlow

  def write_frame_ra(flow, i):
    dir = "./Running_Avg_Frames/" + str(i).zfill(6) + ".flo"
    writeFlow(dir, flow)

  def write_frame_avg(flow, i):
    dir = "./Average_Frames/" + str(i).zfill(6) + ".flo"
    writeFlow(dir, flow)

  def average_list(list1):
    length_list = len(list1)
    temp_addition = 0
    for i in range(0, length_list):
        temp_addition += list1[i]
    temp_val = temp_addition / length_list
    return temp_val
    # try:
    #   return (list1[0] + list1[1]) / 2
    # except:
    #   print("Error in averaging")

  def make_flow(flo):
    tag = np.fromfile(flo, np.float32, count=1)[0]
    width = np.fromfile(flo, np.int32, count=1)[0]
    height = np.fromfile(flo, np.int32, count=1)[0]
    nbands = 2
    tmp = np.fromfile(flo, np.float32, count= nbands * width * height)
    flow = np.resize(tmp, (int(height), int(width), int(nbands)))
    return flow

  if no_average_frames != None:
    flow_list = [None] * no_average_frames
    index_flow = 0
    index_name = 0

  numerator = 0
  denominator = 0
  index_name = 0

  # !mkdir ./Running_Avg_Frames
  # !mkdir ./Average_Frames
  dir = './output/inference/run.epoch-0-flow-field/'

  for i, flo_file in enumerate(sorted(os.listdir(dir))):
    if flo_file[-3:] != "flo":
      continue

    path = Path(dir + flo_file)
    with path.open(mode='r') as flo:
      final_flo = make_flow(flo) # From their own code

      if running_average == True and no_average_frames == None:
        # Method 4
        if denominator == 0:
          numerator += final_flo
          denominator = 1
        else:
          numerator += final_flo
          denominator +=1

          average_flow = numerator/denominator

          write_frame(average_flow, index_name)
          index_name += 1
          
        # os.remove(dir + flo_file)

      # Method 3
      if running_average == False and no_average_frames != None:
        if (index_flow % no_average_frames == 0) and index_flow != 0:
          average_flow = average_list(flow_list)
          write_frame_ra(average_flow, index_name)
          index_flow = 0
          index_name += 1

        flow_list[index_flow] = final_flo
        index_flow += 1

        if i == len(os.listdir(dir)) - 1:
          average_flow = average_list(flow_list)
          write_frame_avg(average_flow, index_name)

        os.remove(dir + flo_file)

      # Method 1
      # if i == 0:
      #   flow_list[0] = flow
      # else:
      #   flow_list[1] = flow
      #   average_flow = average_list(flow_list)
      #   write_frame(average_flow, i-1)
      #   flow_list[0] = average_flow

      # Method 2
      # if index_flow == 0:
      #   flow_list[index_flow] = flow
      #   index_flow += 1
      # else:
      #   flow_list[index_flow] = flow
      #   index_flow = 0
      #   average_flow = average_list(flow_list)
      #   write_frame(average_flow, index_name)
      #   index_name += 1

# %% [markdown]
# # Visualizing

# %% [markdown]
# ## Flowiz technique

# %%
# if visualize == True:

#   !python -m flowiz \
#   ./Flo/*.flo \
#   -o FlowFrames \
#   -v FlowVideo \
#   -r 15

#   !mv ./FlowVideo/000000.flo.mp4 './FlowVideo/$flow_video_name'
# Out:
# > Rendering images [.png] from the flows [.flo]
# > Created directory: FlowFrames
# FlowFrames/000122.flo.png: 100% 123/123 [00:41<00:00,  3.00it/s]
# > Compiling [.mp4] video from the flow images [.png]
# > Saving video as: FlowVideo/000000.flo.mp4

# %%
# from google.colab import files
# files.download('./FlowVideo/'+flow_video_name)

# %% [markdown]
# ## Scipy Method

# %% [markdown]
# ### Install scipy as some tensorflow functionality requires updated scipy

# %%
import time

start_time = time.time()

# !pip install scipy==1.4.1
# Out:
# Collecting scipy==1.4.1
#   Downloading https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1MB)
#      |████████████████████████████████| 26.1MB 113kB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy==1.4.1) (1.18.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.1.0
#     Uninstalling scipy-1.1.0:
#       Successfully uninstalled scipy-1.1.0
# ERROR: Operation cancelled by user

# %% [markdown]
# ### Define show_flow() for visualization.
#  Original Source https://github.com/sampepose/flownet2-tf/blob/master/src/flowlib.py

# %%
# Source:https://github.com/sampepose/flownet2-tf/blob/master/src/flowlib.py
import matplotlib.pyplot as plt
import numpy as np

UNKNOWN_FLOW_THRESH = 1e7
def show_flow(filename):
    """
    visualize optical flow map using matplotlib
    :param filename: optical flow file
    :return: None
    """
    flow = read_flow(filename)
    img = flow_to_image(flow)
    plt.imshow(img)
    plt.show()

def read_flow(filename):
    """
    read optical flow from Middlebury .flo file
    :param filename: name of the flow file
    :return: optical flow data in matrix
    """
    f = open(filename, 'rb')
    magic = np.fromfile(f, np.float32, count=1)
    data2d = None

    if 202021.25 != magic:
        print ('Magic number incorrect. Invalid .flo file')
    else:
        w = int(np.fromfile(f, np.int32, count=1)[0])
        h = int(np.fromfile(f, np.int32, count=1)[0])
        #print("Reading %d x %d flo file" % (h, w))
        data2d = np.fromfile(f, np.float32, count=2 * w * h)
        # reshape data into 3D array (columns, rows, channels)
        data2d = np.resize(data2d, (h, w, 2))
    f.close()
    return data2d

def flow_to_image(flow):
    """
    Convert flow into middlebury color code image
    :param flow: optical flow map
    :return: optical flow image in middlebury color
    """
    u = flow[:, :, 0]
    v = flow[:, :, 1]

    maxu = -999.
    maxv = -999.
    minu = 999.
    minv = 999.

    idxUnknow = (abs(u) > UNKNOWN_FLOW_THRESH) | (abs(v) > UNKNOWN_FLOW_THRESH)
    u[idxUnknow] = 0
    v[idxUnknow] = 0

    maxu = max(maxu, np.max(u))
    minu = min(minu, np.min(u))

    maxv = max(maxv, np.max(v))
    minv = min(minv, np.min(v))

    rad = np.sqrt(u ** 2 + v ** 2)
    maxrad = max(-1, np.max(rad))

    #print( "max flow: %.4f\nflow range:\nu = %.3f .. %.3f\nv = %.3f .. %.3f" % (maxrad, minu,maxu, minv, maxv))

    u = u/(maxrad + np.finfo(float).eps)
    v = v/(maxrad + np.finfo(float).eps)

    img = compute_color(u, v)

    idx = np.repeat(idxUnknow[:, :, np.newaxis], 3, axis=2)
    img[idx] = 0

    return np.uint8(img)


def compute_color(u, v):
    """
    compute optical flow color map
    :param u: optical flow horizontal map
    :param v: optical flow vertical map
    :return: optical flow in color code
    """
    [h, w] = u.shape
    img = np.zeros([h, w, 3])
    nanIdx = np.isnan(u) | np.isnan(v)
    u[nanIdx] = 0
    v[nanIdx] = 0

    colorwheel = make_color_wheel()
    ncols = np.size(colorwheel, 0)

    rad = np.sqrt(u**2+v**2)

    a = np.arctan2(-v, -u) / np.pi

    fk = (a+1) / 2 * (ncols - 1) + 1

    k0 = np.floor(fk).astype(int)

    k1 = k0 + 1
    k1[k1 == ncols+1] = 1
    f = fk - k0

    for i in range(0, np.size(colorwheel,1)):
        tmp = colorwheel[:, i]
        col0 = tmp[k0-1] / 255
        col1 = tmp[k1-1] / 255
        col = (1-f) * col0 + f * col1

        idx = rad <= 1
        col[idx] = 1-rad[idx]*(1-col[idx])
        notidx = np.logical_not(idx)

        col[notidx] *= 0.75
        img[:, :, i] = np.uint8(np.floor(255 * col*(1-nanIdx)))

    return img


def make_color_wheel():
    """
    Generate color wheel according Middlebury color code
    :return: Color wheel
    """
    RY = 15
    YG = 6
    GC = 4
    CB = 11
    BM = 13
    MR = 6

    ncols = RY + YG + GC + CB + BM + MR

    colorwheel = np.zeros([ncols, 3])

    col = 0

    # RY
    colorwheel[0:RY, 0] = 255
    colorwheel[0:RY, 1] = np.transpose(np.floor(255*np.arange(0, RY) / RY))
    col += RY

    # YG
    colorwheel[col:col+YG, 0] = 255 - np.transpose(np.floor(255*np.arange(0, YG) / YG))
    colorwheel[col:col+YG, 1] = 255
    col += YG

    # GC
    colorwheel[col:col+GC, 1] = 255
    colorwheel[col:col+GC, 2] = np.transpose(np.floor(255*np.arange(0, GC) / GC))
    col += GC

    # CB
    colorwheel[col:col+CB, 1] = 255 - np.transpose(np.floor(255*np.arange(0, CB) / CB))
    colorwheel[col:col+CB, 2] = 255
    col += CB

    # BM
    colorwheel[col:col+BM, 2] = 255
    colorwheel[col:col+BM, 0] = np.transpose(np.floor(255*np.arange(0, BM) / BM))
    col += + BM

    # MR
    colorwheel[col:col+MR, 2] = 255 - np.transpose(np.floor(255 * np.arange(0, MR) / MR))
    colorwheel[col:col+MR, 0] = 255

    return colorwheel

# %% [markdown]
# ### Save Flo files as images

# %%
import os
import PIL.Image
def mkdir_ifnotexists(dir):
    if os.path.exists(dir):
        return
    os.mkdir(dir)

if no_average_frames != None:
  directory = "./Average_Frames"

elif running_average == True:
  directory = "./Running_Avg_Frames"

else:
  directory = '/content/flownet2pytorch/output/inference/run.epoch-0-flow-field/'

# flo_pth='/content/flownet2pytorch/output/inference/run.epoch-0-flow-field/'
flo_pth = directory
flos=[flo_pth + f for f in os.listdir(flo_pth)]
mkdir_ifnotexists('./FlowFrames')
length = len(flos)
for i in range(length):
  if flos[i][-3:] == "flo":
    print(i+1, "/", length)
    PIL.Image.fromarray(flow_to_image(read_flow(flos[i]))).save('./FlowFrames/'+os.path.basename(flos[i])+'.png')
    os.remove(flos[i])
# Out:
# 1 / 123
# 2 / 123
# 3 / 123
# 4 / 123
# 5 / 123
# 6 / 123
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-65294d55bec9> in <module>()
#      19   if flos[i][-3:] == "flo":
#      20     print(i+1, "/", length)
# ---> 21     PIL.Image.fromarray(flow_to_image(read_flow(flos[i]))).save('./FlowFrames/'+os.path.basename(flos[i])+'.png')
#      22     os.remove(flos[i])
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     898         chunk(fp, b"eXIf", exif)
#     899
# --> 900     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     901
#     902     chunk(fp, b"IEND", b"")
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     508             else:
#     509                 while True:
# --> 510                     l, s, d = e.encode(bufsize)
#     511                     fp.write(d)
#     512                     if s:
#
# KeyboardInterrupt:

# %%
# !ls ./FlowFrames | wc -l # Use to recheck if number of frames is consistent and nothing went wrong.

# %% [markdown]
# ### Generate video from Flo

# %%
os.system('ffmpeg -r 25 -i FlowFrames/%6d.flo.png -vcodec libx264 -b 10M -y FlowVideo.mp4')

print("My program took", time.time() - start_time, "to run")

# %%
from google.colab import files
files.download('FlowVideo.mp4')

# %%
# from IPython.display import HTML
# from base64 import b64encode
# mp4 = open('FlowVideo.mp4','rb').read()
# data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
# HTML("""
# <video width=400 controls>
#       <source src="%s" type="video/mp4">
# </video>
# """ % data_url)

# %% [markdown]
# # NWPU

# %% [markdown]
# ## Resized Images

# %%
import numpy as np

# From flownet code
def flow_size():
  flo = open("./output/inference/run.epoch-0-flow-field/000000.flo", "r") 
  tag = np.fromfile(flo, np.float32, count=1)[0]
  width = np.fromfile(flo, np.int32, count=1)[0]
  height = np.fromfile(flo, np.int32, count=1)[0]
    
  return height, width

# %%
height, width = flow_size()
height, width
# Out:
# (1024, 1920)

# %%
from PIL import Image

dir = "./frames"

for frame in sorted(os.listdir(dir)):
  if frame[-3:] == 'png':

    # Open image and resize
    image = Image.open(dir + "/" + frame)
    new_image = image.resize((width, height))

    # Remove image and write new one
    os.remove(dir + "/" + frame)
    new_image.save(dir + "/" + frame)

# %% [markdown]
# ## Setup text file

# %%
f = open("test1.txt", "w")

i = 0
for frame in sorted(os.listdir("./frames")):

  if frame[-3:] == 'png':

    if i != 0:
      f.write("\n")
      
    f.write(frame[:-4])
    i += 1

f.close()
# Out:
# 000000
# 000001
# 000002
# 000003
# 000004
# 000005
# 000006
# 000007
# 000008
# 000009
# 000010
# 000011
# 000012
# 000013
# 000014
# 000015
# 000016
# 000017
# 000018
# 000019
# 000020
# 000021
# 000022
# 000023
# 000024
# 000025
# 000026
# 000027
# 000028
# 000029
# 000030
# 000031
# 000032
# 000033
# 000034
# 000035
# 000036
# 000037
# 000038
# 000039
# 000040
# 000041
# 000042
# 000043
# 000044
# 000045
# 000046
# 000047
# 000048
# 000049
# 000050
# 000051
# 000052
# 000053
# 000054
# 000055
# 000056
# 000057
# 000058
# 000059
# 000060
# 000061
# 000062
# 000063
# 000064
# 000065
# 000066
# 000067
# 000068
# 000069
# 000070
# 000071
# 000072
# 000073
# 000074
# 000075
# 000076
# 000077
# 000078
# 000079
# 000080
# 000081
# 000082
# 000083
# 000084
# 000085
# 000086
# 000087
# 000088
# 000089
# 000090

# %% [markdown]
# ## Import NWPU

# %%
# !gdown --id '1-8vjopZivDbsx3pBihu_8UE2zXwPEMWt'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-8vjopZivDbsx3pBihu_8UE2zXwPEMWt
# To: /content/flownet2pytorch/NWPU.zip
# 764MB [00:03, 199MB/s]

# %%
# !unzip NWPU.zip
# Out:
# Archive:  NWPU.zip
#    creating: NWPU-Crowd-Sample-Code/
#   inflating: NWPU-Crowd-Sample-Code/val.txt
#   inflating: NWPU-Crowd-Sample-Code/LICENSE
#   inflating: NWPU-Crowd-Sample-Code/trainer.py
#   inflating: NWPU-Crowd-Sample-Code/validation.py
#   inflating: NWPU-Crowd-Sample-Code/.gitignore
#  extracting: NWPU-Crowd-Sample-Code/__init__.py
#   inflating: NWPU-Crowd-Sample-Code/README.md
#   inflating: NWPU-Crowd-Sample-Code/requirements.txt
#    creating: NWPU-Crowd-Sample-Code/NWPU-Crowd/
#    creating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/
#    creating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1002.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1001.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1003.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1004.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1006.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1005.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1007.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1008.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1009.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1010.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1011.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1012.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1013.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1014.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1015.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1017.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1016.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1018.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1019.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1020.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1021.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1022.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1023.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1024.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1026.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1025.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1027.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1028.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1030.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1029.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1032.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1033.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1031.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1034.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1035.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1036.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1037.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1038.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1039.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1041.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1040.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1042.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1043.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1044.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1046.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1045.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1047.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1048.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1050.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1049.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1051.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1052.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1053.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1054.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1056.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1055.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1057.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1058.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1059.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1061.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1060.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1063.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1062.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1065.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1064.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1066.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1068.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1067.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1069.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1070.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1071.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1072.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1073.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1074.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1076.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1075.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1077.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1078.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1079.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1081.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1080.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1082.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1084.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1083.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1085.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1086.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1087.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1088.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1089.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1090.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1091.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1092.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1094.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1093.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1095.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1096.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1098.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1097.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1099.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1100.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1101.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1103.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1102.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1104.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1106.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1105.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1107.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1108.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1109.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1111.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1110.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1112.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1113.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1114.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1116.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1115.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1117.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1118.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1119.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1120.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1121.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1123.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1122.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1124.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1126.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1125.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1128.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1127.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1130.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1129.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1131.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1132.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1133.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1134.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1137.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1135.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1136.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1138.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1139.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1140.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1141.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1142.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1144.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1143.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1146.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1145.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1147.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1150.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1149.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1148.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1152.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1151.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1153.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1155.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1154.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1156.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1158.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1157.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1160.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1159.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1161.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1163.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1162.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1165.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1164.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1166.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1167.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1169.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1168.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1170.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1172.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1171.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1173.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1174.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1176.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1175.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1178.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1177.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1179.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1180.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1181.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1182.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1183.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1185.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1184.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1187.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1186.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1188.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1189.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1191.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1190.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/1193.jpg
#   inflating: NWPU-Crowd-Sample-Code/NWPU-Crowd/min_576x768_mod16_2048/img/